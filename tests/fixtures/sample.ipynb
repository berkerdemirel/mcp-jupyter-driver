# %% [markdown]
# # Sample notebook
#
# A fixture used for smoke-testing mcp-jupyter-driver.

# %%
import math
x = [math.sin(i / 10) for i in range(50)]
len(x)

# %%
print('min', min(x), 'max', max(x), 'mean', sum(x) / len(x))
